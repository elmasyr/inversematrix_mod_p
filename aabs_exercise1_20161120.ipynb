# %%
''' import libraries and define some setup '''
import pandas as pd
# %matplotlib inline

# %%
df=pd.read_csv('group3.csv', header=0, sep=';', encoding='utf-8') # read data
df.shape # check size
# Out:
# (35282, 2)

# %%
# get only the valid values and ignore additional white space
df=df[df.index<7458]
df.shape # dataset size
# Out:
# (7458, 2)

# %%
# checks
print df.head()
print df.tail()
# Out:
#       timestamp      green
# 0  1.479293e+12  2131004.0
# 1  1.479293e+12  2130976.0
# 2  1.479293e+12  2129588.0
# 3  1.479293e+12  2131550.0
# 4  1.479293e+12  2132414.0
#          timestamp      green
# 7453  1.479293e+12  1599606.0
# 7454  1.479293e+12  1595576.0
# 7455  1.479293e+12  1589228.0
# 7456  1.479293e+12  1584442.0
# 7457  1.479293e+12  1580858.0

# %%
# rename column
df.columns = ['ts', 'signal']
# make new variable "seconds"
df['index']=df.index
df['sec']=df['index']/20

# %%
# checks
print df.head()
print df.tail()
# Out:
#              ts     signal  index   sec
# 0  1.479293e+12  2131004.0      0  0.00
# 1  1.479293e+12  2130976.0      1  0.05
# 2  1.479293e+12  2129588.0      2  0.10
# 3  1.479293e+12  2131550.0      3  0.15
# 4  1.479293e+12  2132414.0      4  0.20
#                 ts     signal  index     sec
# 7453  1.479293e+12  1599606.0   7453  372.65
# 7454  1.479293e+12  1595576.0   7454  372.70
# 7455  1.479293e+12  1589228.0   7455  372.75
# 7456  1.479293e+12  1584442.0   7456  372.80
# 7457  1.479293e+12  1580858.0   7457  372.85

# %% [markdown]
# ## ploting the whole data
# ticks on x-axis should show the different exercise steps

# %%
import seaborn as sns

#seaborn settings
sns.set_palette("deep", desat=.6)
sns.set_style("whitegrid")

# %%
df.plot(x=['sec'],y= ['signal'],xticks=[60, 120, 180, 240, 300, 330, 390], figsize=(12, 6));

# %% [markdown]
# ### Task 1 with non-filtered data
# 15 sec from 1. Sitting still, both hands on the table, breathing normally 1 min

# %%
from numpy import *
from pylab import *
import numpy as np
import peakutils

s = 30 # start time in seconds
e = 45 # end time in seconds

df_temp=df[(df.sec>=s) & (df.sec<e)]
data = np.array(df_temp.signal)
x=np.array(df_temp.index)
#tresh =(np.max(data[:50])-np.min(data[:50])) / np.std(data[:50])*10
tresh=0.10

lmax = ((diff(sign(diff(data))) < 0)).nonzero()[0] + 1 # local max
maxpeaks = peakutils.indexes(data, thres=tresh, min_dist=10)

print len(lmax), 'peaks in', (e-s), 'seconds'
print len(maxpeaks), 'max peaks in', (e-s), 'seconds'
# df_temp.plot(x=['sec'],y= ['signal'], figsize=(12, 6));

plt.figure(figsize=(12, 6))
plot(x,data)
# plot(x[lmin], data[lmin], "o", label="min")
# plot(x[lmax], data[lmax], "o", label="max")
plot(x[maxpeaks], data[maxpeaks], "o", label="max peaks")
legend()
title('Non-filtered data')
show()
# Out:
# 32 peaks in 15 seconds
# 17 max peaks in 15 seconds

# %% [markdown]
# ### Task 2 with non-filtered data
# 15 sec from 2. Sitting still, hand (the one with the device) towards ceiling, breathing normally 1 min

# %%
s = 90 # start time in seconds
e = 105 # end time in seconds

df_temp=df[(df.sec>=s) & (df.sec<e)]
data = np.array(df_temp.signal)
x=np.array(df_temp.index)
tresh=0.10

lmax = ((diff(sign(diff(data))) < 0)).nonzero()[0] + 1 # local max
maxpeaks = peakutils.indexes(data, thres=tresh, min_dist=10)

print len(lmax), 'peaks in', (e-s), 'seconds'
print len(maxpeaks), 'max peaks in', (e-s), 'seconds'
# df_temp.plot(x=['sec'],y= ['signal'], figsize=(12, 6));

plt.figure(figsize=(12, 6))
plot(x,data)
# plot(x[lmin], data[lmin], "o", label="min")
# plot(x[lmax], data[lmax], "o", label="max")
plot(x[maxpeaks], data[maxpeaks], "o", label="max peaks")
legend()
title('Non-filtered data')
show()
# Out:
# 58 peaks in 15 seconds
# 18 max peaks in 15 seconds

# %% [markdown]
# ### Task 3 with non-filtered data
# 15 sec from 3. Standing still, both hands hanging, breathing normally 1 min

# %%
s = 150 # start time in seconds
e = 165 # end time in seconds

df_temp=df[(df.sec>=s) & (df.sec<e)]
data = np.array(df_temp.signal)
x=np.array(df_temp.index)
tresh=0.10

lmax = ((diff(sign(diff(data))) < 0)).nonzero()[0] + 1 # local max
maxpeaks = peakutils.indexes(data, thres=tresh, min_dist=10)

print len(lmax), 'peaks in', (e-s), 'seconds'
print len(maxpeaks), 'max peaks in', (e-s), 'seconds'
# df_temp.plot(x=['sec'],y= ['signal'], figsize=(12, 6));

plt.figure(figsize=(12, 6))
plot(x,data)
# plot(x[lmin], data[lmin], "o", label="min")
# plot(x[lmax], data[lmax], "o", label="max")
plot(x[maxpeaks], data[maxpeaks], "o", label="max peaks")
legend()
title('Non-filtered data')
show()
# Out:
# 26 peaks in 15 seconds
# 17 max peaks in 15 seconds

# %% [markdown]
# ### Task 4 with non-filtered data
# 15 sec from 4. Walking around (slowly), breathing normally 1 min

# %%
s = 210 # start time in seconds
e = 225 # end time in seconds

df_temp=df[(df.sec>=s) & (df.sec<e)]
data = np.array(df_temp.signal)
x=np.array(df_temp.index)
tresh=0.10

lmax = ((diff(sign(diff(data))) < 0)).nonzero()[0] + 1 # local max
maxpeaks = peakutils.indexes(data, thres=tresh, min_dist=10)

print len(lmax), 'peaks in', (e-s), 'seconds'
print len(maxpeaks), 'max peaks in', (e-s), 'seconds'
# df_temp.plot(x=['sec'],y= ['signal'], figsize=(12, 6));

plt.figure(figsize=(12, 6))
plot(x,data)
# plot(x[lmin], data[lmin], "o", label="min")
# plot(x[lmax], data[lmax], "o", label="max")
plot(x[maxpeaks], data[maxpeaks], "o", label="max peaks")
legend()
title('Non-filtered data')
show()
# Out:
# 36 peaks in 15 seconds
# 19 max peaks in 15 seconds

# %% [markdown]
# ### Task 5 with non-filtered data
# 15 sec from 5. Sitting still, holding your breath for 30s

# %%
s = 250 # start time in seconds
e = 265 # end time in seconds

df_temp=df[(df.sec>=s) & (df.sec<e)]
data = np.array(df_temp.signal)
x=np.array(df_temp.index)
tresh=0.10

lmax = ((diff(sign(diff(data))) < 0)).nonzero()[0] + 1 # local max
maxpeaks = peakutils.indexes(data, thres=tresh, min_dist=10)

print len(lmax), 'peaks in', (e-s), 'seconds'
print len(maxpeaks), 'max peaks in', (e-s), 'seconds'
# df_temp.plot(x=['sec'],y= ['signal'], figsize=(12, 6));

plt.figure(figsize=(12, 6))
plot(x,data)
# plot(x[lmin], data[lmin], "o", label="min")
# plot(x[lmax], data[lmax], "o", label="max")
plot(x[maxpeaks], data[maxpeaks], "o", label="max peaks")
legend()
title('Non-filtered data')
show()
# Out:
# 37 peaks in 15 seconds
# 19 max peaks in 15 seconds

# %% [markdown]
# ### Pause with non-filtered data
# 30 second pause

# %%
s = 300 # start time in seconds
e = 330 # end time in seconds

df_temp=df[(df.sec>=s) & (df.sec<e)]
data = np.array(df_temp.signal)
x=np.array(df_temp.index)
tresh=0.10

lmax = ((diff(sign(diff(data))) < 0)).nonzero()[0] + 1 # local max
maxpeaks = peakutils.indexes(data, thres=tresh, min_dist=10)

print len(lmax), 'peaks in', (e-s), 'seconds'
print len(maxpeaks), 'max peaks in', (e-s), 'seconds'
# df_temp.plot(x=['sec'],y= ['signal'], figsize=(12, 6));

plt.figure(figsize=(12, 6))
plot(x,data)
# plot(x[lmin], data[lmin], "o", label="min")
# plot(x[lmax], data[lmax], "o", label="max")
plot(x[maxpeaks], data[maxpeaks], "o", label="max peaks")
legend()
title('Non-filtered data')
show()
# Out:
# 40 peaks in 30 seconds
# 33 max peaks in 30 seconds

# %% [markdown]
# ### Task 6 with non-filtered data
# 6. Optional try Valsalva maneuver while sitting (after 1 min recovery from holding your breath)

# %%
s = 330 # start time in seconds
e = 370 # end time in seconds

df_temp=df[(df.sec>=s) & (df.sec<e)]
data = np.array(df_temp.signal)
x=np.array(df_temp.index)
sec=np.array(df_temp.sec)
tresh=0.10

lmax = ((diff(sign(diff(data))) < 0)).nonzero()[0] + 1 # local max
maxpeaks = peakutils.indexes(data, thres=tresh, min_dist=10)

print len(lmax), 'peaks in', (e-s), 'seconds'
print len(maxpeaks), 'max peaks in', (e-s), 'seconds'
# df_temp.plot(x=['sec'],y= ['signal'], figsize=(12, 6));

plt.figure(figsize=(12, 6))
plot(sec,data)
# plot(x[lmin], data[lmin], "o", label="min")
# plot(x[lmax], data[lmax], "o", label="max")
plot(sec[maxpeaks], data[maxpeaks], "o", label="max peaks")
legend()
title('Non-filtered data')
show()
# Out:
# 70 peaks in 40 seconds
# 41 max peaks in 40 seconds

# %%
from scipy.signal import butter, lfilter
from scipy.signal import freqz

# %%
# # in case this is needed
# from sklearn import preprocessing
# std_scaler = preprocessing.StandardScaler() # z-score scaler
# def normal(dataset):
#     '''funtion to be caller in normalization'''
#     return std_scaler.fit_transform(dataset)

# %%
import copy

df_signal = df.copy()
#s0 = normal(df_signal)
s0 = df_signal
s = np.array(s0)

len(s)
# Out:
# 7458

# %%
# http://scipy-cookbook.readthedocs.io/items/ButterworthBandpass.html

def butter_bandpass(lowcut, highcut, fs, order):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a


def butter_bandpass_filter(data, lowcut, highcut, fs, order):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = lfilter(b, a, data)
    return y

# %%
# Trying to implement Butterworth Bandpass
# Sample rate and desired cutoffs
fs = 20.
lowcut = 0.45 # taken from example, not sure if this is ok
highcut = 0.65 # taken from example, not sure if this is ok
order=17 # just testing, not sure if this is optimal either

filt = butter_bandpass_filter(s, lowcut, highcut, fs, order)

# %%
# reorganizing data
df_filt=pd.DataFrame(filt)
df_filt.columns = ['s0', 's1', 's2', 's3']
df_filt['sec']=df['sec']

# %%
df_filt.head()
# Out:
#              s0            s1            s2            s3   sec
# 0  2.993152e-14  9.829242e-13  1.609086e-11  1.753571e-10  0.00
# 1  2.993152e-14  9.829242e-13  1.609086e-11  1.753571e-10  0.05
# 2  2.993152e-14  9.829242e-13  1.609086e-11  1.753571e-10  0.10
# 3  2.993152e-14  9.829242e-13  1.609086e-11  1.753571e-10  0.15
# 4  2.993152e-14  9.829242e-13  1.609086e-11  1.753571e-10  0.20

# %%
# checking how many peaks with all data

s = 0 # start time in seconds
e = 330 # end time in seconds
df_temp=df[(df.sec>=s) & (df.sec<e)]
data = np.array(df_temp['signal'])
lmax = (diff(sign(diff(data))) < 0).nonzero()[0] + 1 # local max
maxpeaks = peakutils.indexes(data, thres=0.15, min_dist=10)
print len(lmax), 'peaks',len(maxpeaks),'maxpeaks in', (e-s), 'seconds'
# Out:
# 697 peaks 344 maxpeaks in 330 seconds

# %%
# testing with all data, how many peaks per filtered channel

s = 0 # start time in seconds
e = 330 # end time in seconds
df_temp=df_filt[(df_filt.sec>=s) & (df_filt.sec<e)]
filtlist=['s0','s1','s2','s3']
for filtered in filtlist:
    data = np.array(df_temp[filtered])
    lmax = (diff(sign(diff(data))) < 0).nonzero()[0] + 1 # local max
    maxpeaks = peakutils.indexes(data, thres=0.15, min_dist=10)
    print len(lmax), 'peaks',len(maxpeaks),'maxpeaks in', (e-s), 'seconds'
# Out:
# 0 peaks 0 maxpeaks in 330 seconds
# 668 peaks 318 maxpeaks in 330 seconds
# 720 peaks 323 maxpeaks in 330 seconds
# 734 peaks 325 maxpeaks in 330 seconds

# %%
# testing with 2. task data

s = 90 # start time in seconds
e = 105 # end time in seconds
df_temp=df_filt[(df_filt.sec>=s) & (df_filt.sec<e)]
filtlist=['s0','s1','s2','s3']
for filtered in filtlist:
    data = np.array(df_temp[filtered])
    lmax = (diff(sign(diff(data))) < 0).nonzero()[0] + 1 # local max
    maxpeaks = peakutils.indexes(data, thres=0.15, min_dist=10)
    print len(lmax), 'peaks',len(maxpeaks),'maxpeaks in', (e-s), 'seconds'
# Out:
# 0 peaks 0 maxpeaks in 15 seconds
# 40 peaks 16 maxpeaks in 15 seconds
# 47 peaks 16 maxpeaks in 15 seconds
# 51 peaks 18 maxpeaks in 15 seconds

# %%
#df_temp['s0'].plot(figsize=(12, 6))
df_temp.plot(x=['sec'],y= ['s0'], xticks=range(s,e), figsize=(12, 6));

# %%
df_temp.plot(x=['sec'],y= ['s1'], figsize=(12, 6));

# %%
df_temp.plot(x=['sec'],y= ['s2'], figsize=(12, 6));

# %%
df_temp.plot(x=['sec'],y= ['s3'], figsize=(12, 6));

# %%
s = 90 # start time in seconds
e = 105 # end time in seconds

df_orig=df[(df.sec>=s) & (df.sec<e)]
data = np.array(df_orig.signal)
lmax = (diff(sign(diff(data))) < 0).nonzero()[0] + 1 # local max

print len(lmax), 'peaks in', (e-s), 'seconds'
df_orig.plot(x=['sec'],y= ['signal'], figsize=(12, 6));
# Out:
# 58 peaks in 15 seconds

# %% [markdown]
# ### Using filtered s1

# %%
# not sure which channel data should be used, using filtering with s3 values
df['filtered']=df_filt['s3']

# %%
df.head(2)
# Out:
#              ts     signal  index   sec      filtered
# 0  1.479293e+12  2131004.0      0  0.00  1.753571e-10
# 1  1.479293e+12  2130976.0      1  0.05  1.753571e-10

# %%
s = 30 # start time in seconds
e = 45 # end time in seconds

df_new=df[(df.sec>=s) & (df.sec<e)]
data = np.array(df_new.filtered)
x=np.array(df_temp.index)
tresh=0.10

lmax = (diff(sign(diff(data))) < 0).nonzero()[0] + 1 # local max
maxpeaks = peakutils.indexes(data, thres=tresh, min_dist=10)

print len(lmax), 'peaks in', (e-s), 'seconds'
print len(maxpeaks), 'max peaks in', (e-s), 'seconds'

plt.figure(figsize=(12, 6))
plot(x,data)
plot(x[maxpeaks], data[maxpeaks], "o", label="max peaks")
legend()
title('Filtered data')
show()

df_temp=df[(df.sec>=s) & (df.sec<e)]
data = np.array(df_temp.signal)
x=np.array(df_temp.index)

lmax = ((diff(sign(diff(data))) < 0)).nonzero()[0] + 1 # local max
maxpeaks = peakutils.indexes(data, thres=tresh, min_dist=10)

print len(lmax), 'peaks in', (e-s), 'seconds'
print len(maxpeaks), 'max peaks in', (e-s), 'seconds'

plt.figure(figsize=(12, 6))
plot(x,data)
# plot(x[lmin], data[lmin], "o", label="min")
# plot(x[lmax], data[lmax], "o", label="max")
plot(x[maxpeaks], data[maxpeaks], "o", label="max peaks")
legend()
title('Non-filtered data')
show()
# Out:
# 32 peaks in 15 seconds
# 18 max peaks in 15 seconds
# 32 peaks in 15 seconds
# 17 max peaks in 15 seconds

# %%
s = 250 # start time in seconds
e = 265 # end time in seconds

df_new=df[(df.sec>=s) & (df.sec<e)]
data = np.array(df_new.filtered)
x=np.array(df_temp.index)
tresh=0.10

lmax = (diff(sign(diff(data))) < 0).nonzero()[0] + 1 # local max
maxpeaks = peakutils.indexes(data, thres=tresh, min_dist=10)

print len(lmax), 'peaks in', (e-s), 'seconds'
print len(maxpeaks), 'max peaks in', (e-s), 'seconds'

plt.figure(figsize=(12, 6))
plot(x,data)
plot(x[maxpeaks], data[maxpeaks], "o", label="max peaks")
legend()
title('Filtered data')
show()

df_temp=df[(df.sec>=s) & (df.sec<e)]
data = np.array(df_temp.signal)
x=np.array(df_temp.index)

lmax = ((diff(sign(diff(data))) < 0)).nonzero()[0] + 1 # local max
maxpeaks = peakutils.indexes(data, thres=tresh, min_dist=10)

print len(lmax), 'peaks in', (e-s), 'seconds'
print len(maxpeaks), 'max peaks in', (e-s), 'seconds'

plt.figure(figsize=(12, 6))
plot(x,data)
# plot(x[lmin], data[lmin], "o", label="min")
# plot(x[lmax], data[lmax], "o", label="max")
plot(x[maxpeaks], data[maxpeaks], "o", label="max peaks")
legend()
title('Non-filtered data')
show()
# Out:
# 41 peaks in 15 seconds
# 18 max peaks in 15 seconds
# 37 peaks in 15 seconds
# 19 max peaks in 15 seconds
